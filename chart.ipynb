# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

productA = np.array([120, 130, 125])
productB = np.array([150, 160, 170])
productC = np.array([100, 110, 105])
months = np.array(["Jan", "Feb", "Mar"])

sales = {"month":months,
       "product A":productA,
        "product B":productB,
        "product C": productC
       }
g = pd.DataFrame(sales)
print(g)
print(g.describe)
# Out:
#   month  product A  product B  product C
# 0   Jan        120        150        100
# 1   Feb        130        160        110
# 2   Mar        125        170        105
# <bound method NDFrame.describe of   month  product A  product B  product C
# 0   Jan        120        150        100
# 1   Feb        130        160        110
# 2   Mar        125        170        105>

# %% [markdown]
# # mean():
# gets the average of the elements in the dataframe
# # min():
# gets the minimum value number in the dataframe
# # count():
# gets the number of the chosen value that exist in the dataframe

# %%
plt.plot(months, productA)

plt.plot(months, productB)

plt.plot(months, productC)

# %% [markdown]
# # Line Chart:
# The chart is showing 3 itmes sales in the first 3 month of the year.
# Product A is shown in blue
# Product B is shown in orange
# Product C is shown in green

# %% [markdown]
# # Monthly sales Media:

# %%
med = g.median(axis=0, numeric_only=True)
print(med)
plt.plot(med,"bo-")
plt.title("Median Per Product")
plt.xlabel("Product")
plt.ylabel("Monthly Sales")
# Out:
# product A    125.0
# product B    160.0
# product C    105.0
# dtype: float64
# Text(0, 0.5, 'Monthly Sales')

# %% [markdown]
# ## Added new funtions called  median.
